# %% [markdown]
# SITE:https://matplotlib.org/
#
# Matplotlib é uma biblioteca em Python utilizada para criação de gráficos e visualizações de dados. Ela oferece uma ampla gama de funcionalidades para criar diferentes tipos de gráficos, incluindo gráficos de linha, dispersão, barras, histogramas, pizza, entre outros.

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6]
y =[10,20,35,40,50,99]

fig, ax = plt.subplots()
ax.plot(x,y)
plt.show()

# %% [markdown]
#  o código gera um gráfico da função seno no intervalo de 0 a 2π com 200 pontos e o exibe utilizando a biblioteca matplotlib.

# %%
import numpy as np

x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=3.0)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
